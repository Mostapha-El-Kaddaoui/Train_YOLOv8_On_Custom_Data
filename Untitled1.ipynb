# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics # install YOLOV8

from IPython.display import display, Image
import os
HOME = os.getcwd()
print(HOME)

from ultralytics import YOLO
model = YOLO('yolov8l.pt') # here i'am using l version so you can use other versions like "yolov8n"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 kB 23.5 MB/s eta 0:00:00
# ...
# /content
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Moroccan-Tajine-1 in yolov8:: 100%|██████████| 36/36 [00:00<00:00, 2921.90it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="KEY") # here you must paste your key
project = rf.workspace("most-alpha").project("moroccan-tajine")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8l.pt data={dataset.location}/data.yaml  epochs=5 imgsz=640 conf=0.9 # here we try to train yolov8l on our custom data , we specified 5 epochs (number of retraitements), image size 640 , and 0.9 for decision
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source=/content/drive/MyDrive/tajin4.jpeg # here we try to make some detections ,
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 268 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/drive/MyDrive/tajin4.jpeg: 640x640 1 Tajine, 3608.7ms
# Speed: 22.4ms preprocess, 3608.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source=/content/drive/MyDrive/1012185-VTT.jpg
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 268 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/drive/MyDrive/1012185-VTT.jpg: 448x640 3 Tajines, 1918.0ms
# Speed: 2.8ms preprocess, 1918.0ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml  epochs=20 imgsz=640 conf=0.9
# here we are trying to train yolov8n
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 69.2MB/s]
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source=/content/drive/MyDrive/1012185-VTT.jpg
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 268 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/drive/MyDrive/1012185-VTT.jpg: 448x640 3 Tajines, 1930.7ms
# Speed: 3.8ms preprocess, 1930.7ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
